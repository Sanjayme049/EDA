# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjayme049/EDA/blob/main/Pandas6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
people = {
    "first":["Corey", "Jane", "John"],
    "last":["Schafer", "Doe", "Doe"],
    "email":["CoreyMschafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com"]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMschafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    Corey Schafer
# 1         Jane Doe
# 2         John Doe
# dtype: object

# %%
df['full_name'] = df['first'] + ' ' +df['last']

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMschafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@gmail.com       Jane Doe
# 2   John      Doe        JohnDoe@gmail.com       John Doe

# %%
df.drop(columns = ['first', 'last'], inplace=True)

# %%
df
# Out:
#                      email      full_name
# 0  CoreyMschafer@gmail.com  Corey Schafer
# 1        JaneDoe@gmail.com       Jane Doe
# 2        JohnDoe@gmail.com       John Doe

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@gmail.com       Jane Doe   Jane      Doe
# 2        JohnDoe@gmail.com       John Doe   John      Doe

# %%
df.append({'first': 'Tony'},ignore_index=True)
# Out:
#                      email      full_name  first     last
# 0  CoreyMschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@gmail.com       Jane Doe   Jane      Doe
# 2        JohnDoe@gmail.com       John Doe   John      Doe
# 3                      NaN            NaN   Tony      NaN

# %%
people = {
    "first":["Tony", "Steve"],
    "last":['Stark', 'Rogers'],
    "email":["IronMan@avenge.com", "Cap@avenge.com"]
}

# %%
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df=df.append(df2, ignore_index=True, sort=False)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@gmail.com       Jane Doe   Jane      Doe
# 2        JohnDoe@gmail.com       John Doe   John      Doe
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.drop(index=4)
# Out:
#                      email      full_name  first     last
# 0  CoreyMschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@gmail.com       Jane Doe   Jane      Doe
# 2        JohnDoe@gmail.com       John Doe   John      Doe
# 3       IronMan@avenge.com            NaN   Tony    Stark

# %%
filt = df['last'] == 'Doe'
df.drop(index=df[filt].index)
# Out:
#                      email      full_name  first     last
# 0  CoreyMschafer@gmail.com  Corey Schafer  Corey  Schafer
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers
