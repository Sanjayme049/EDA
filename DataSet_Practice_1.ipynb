# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjayme049/EDA/blob/main/DataSet_Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import glob

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/My Drive/Pandas&Numpy/Datasetpractice_1/FashionDataset.csv')

# %%
df
# Out:
#        Unnamed: 0    BrandName  \
# 0               0         life
# 1               1         only
# 2               2      fratini
# 3               3  zink london
# 4               4         life
# ...           ...          ...
# 30753          21    swarovski
# 30754          22          Nan
# 30755          23       jewelz
# 30756          24      estelle
# 30757          25      estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30753            crystal stylish womens rodhium earrings
# 30754                                                Nan
# 30755                 ethnic gold plated jhumki earrings
# ...

# %%
df.shape
# Out:
# (30758, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30758 non-null  int64
#  1   BrandName   30758 non-null  object
#  2   Deatils     30758 non-null  object
#  3   Sizes       30758 non-null  object
#  4   MRP         30758 non-null  object
#  5   SellPrice   30758 non-null  object
#  6   Discount    30758 non-null  object
#  7   Category    30758 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.9+ MB

# %%
df.head(25)
# Out:
#     Unnamed: 0    BrandName  \
# 0            0         life
# 1            1         only
# 2            2      fratini
# 3            3  zink london
# 4            4         life
# 5            5        kraus
# 6            6         life
# 7            7      fratini
# 8            8         rare
# 9            9         rare
# 10          10         life
# 11          11         life
# 12          12         life
# 13          13         life
# 14          14         life
# 15          15         life
# 16          16         life
# 17          17         life
# 18          18   van heusen
# 19          19         life
# 20          20      fratini
# 21          21         life
# 22          22          Nan
# 23          23         stop
# 24          24         life
#
#                                               Deatils  \
# 0   solid cotton blend collar neck womens a-line d...
# 1   polyester peter pan collar womens blouson dres...
# ...

# %%
#Data Handling and Cleaning

df.drop(columns = ["Unnamed: 0"], axis=1, inplace = True)

# %%
df.head(25)
# Out:
#       BrandName                                            Deatils  \
# 0          life  solid cotton blend collar neck womens a-line d...
# 1          only  polyester peter pan collar womens blouson dres...
# 2       fratini  solid polyester blend wide neck womens regular...
# 3   zink london  stripes polyester sweetheart neck womens dress...
# 4          life  regular fit regular length denim womens jeans ...
# 5         kraus  wide ankle length cotton womens jeans - light ...
# 6          life  printed cotton blend collared womens regular d...
# 7       fratini  embroidered wide neck polyester womens regular...
# 8          rare  floral polyester v neck womens flared dress - ...
# 9          rare  checks cotton boat neck womens regular top - b...
# 10         life  solid square neck cotton womens regular dress ...
# 11         life  regular fit regular length denim womens jeans ...
# 12         life  printed blended round neck womens shift dress ...
# ...

# %%
df.shape
# Out:
# (30758, 7)

# %%
df.isnull().sum()
# Out:
# BrandName    0
# Deatils      0
# Sizes        0
# MRP          0
# SellPrice    0
# Discount     0
# Category     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  30758 non-null  object
#  1   Deatils    30758 non-null  object
#  2   Sizes      30758 non-null  object
#  3   MRP        30758 non-null  object
#  4   SellPrice  30758 non-null  object
#  5   Discount   30758 non-null  object
#  6   Category   30758 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %%
df.nunique()
# Out:
# BrandName      275
# Deatils      23877
# Sizes         1172
# MRP           1097
# SellPrice     2046
# Discount        66
# Category         7
# dtype: int64

# %%
df.head(25)
df.shape
# Out:
# (18374, 7)

# %%
df.replace("Nan", np.nan, inplace= True)

# %%
df.dropna(axis = 0, inplace=True)

# %%
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
# 26885     swiss eagle                     womens analogue metallic watch
# 27290  lawman watches  womens rose gold dial stainless steel analogue...
# 28418  lawman watches  womens silver dial stainless steel analogue wa...
#
#                                          Sizes        MRP SellPrice Discount  \
# ...

# %%
df.head(25)
# Out:
#       BrandName                                            Deatils  \
# 0          life  solid cotton blend collar neck womens a-line d...
# 1          only  polyester peter pan collar womens blouson dres...
# 2       fratini  solid polyester blend wide neck womens regular...
# 3   zink london  stripes polyester sweetheart neck womens dress...
# 4          life  regular fit regular length denim womens jeans ...
# 5         kraus  wide ankle length cotton womens jeans - light ...
# 6          life  printed cotton blend collared womens regular d...
# 7       fratini  embroidered wide neck polyester womens regular...
# 8          rare  floral polyester v neck womens flared dress - ...
# 9          rare  checks cotton boat neck womens regular top - b...
# 10         life  solid square neck cotton womens regular dress ...
# 11         life  regular fit regular length denim womens jeans ...
# 12         life  printed blended round neck womens shift dress ...
# ...

# %%
df.shape
# Out:
# (18374, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18374 entries, 0 to 28418
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  18374 non-null  object
#  1   Deatils    18374 non-null  object
#  2   Sizes      18374 non-null  object
#  3   MRP        18374 non-null  object
#  4   SellPrice  18374 non-null  object
#  5   Discount   18374 non-null  object
#  6   Category   18374 non-null  object
# dtypes: object(7)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#      BrandName                                            Deatils  \
# 0         life  solid cotton blend collar neck womens a-line d...
# 1         only  polyester peter pan collar womens blouson dres...
# 2      fratini  solid polyester blend wide neck womens regular...
# 3  zink london  stripes polyester sweetheart neck womens dress...
# 4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# 4  Westernwear-Women

# %%
df['MRP'] = df['MRP'].str.replace("Rs\n", "")

# %%
df['MRP'] = df['MRP'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18374 entries, 0 to 28418
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  18374 non-null  object
#  1   Deatils    18374 non-null  object
#  2   Sizes      18374 non-null  object
#  3   MRP        18374 non-null  int64
#  4   SellPrice  18374 non-null  object
#  5   Discount   18374 non-null  object
#  6   Category   18374 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.1+ MB

# %%
df['Discount'] = df['Discount'].str.replace('% off', "")

# %%
df['Discount'] = df['Discount'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18374 entries, 0 to 28418
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  18374 non-null  object
#  1   Deatils    18374 non-null  object
#  2   Sizes      18374 non-null  object
#  3   MRP        18374 non-null  int64
#  4   SellPrice  18374 non-null  object
#  5   Discount   18374 non-null  int64
#  6   Category   18374 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 1.1+ MB

# %%
df['SellPrice'] = df['SellPrice'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18374 entries, 0 to 28418
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  18374 non-null  object
#  1   Deatils    18374 non-null  object
#  2   Sizes      18374 non-null  object
#  3   MRP        18374 non-null  int64
#  4   SellPrice  18374 non-null  int64
#  5   Discount   18374 non-null  int64
#  6   Category   18374 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
df['Category'] = df['Category'].str.replace("-Women", "")

# %%
df['Category']
# Out:
# 0        Westernwear
# 1        Westernwear
# 2        Westernwear
# 3        Westernwear
# 4        Westernwear
#             ...
# 26673       Footwear
# 26674       Footwear
# 26885        Watches
# 27290        Watches
# 28418        Watches
# Name: Category, Length: 18374, dtype: object

# %%
df.head()
# Out:
#      BrandName                                            Deatils  \
# 0         life  solid cotton blend collar neck womens a-line d...
# 1         only  polyester peter pan collar womens blouson dres...
# 2      fratini  solid polyester blend wide neck womens regular...
# 3  zink london  stripes polyester sweetheart neck womens dress...
# 4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes   MRP  SellPrice  Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  1699        849        50
# 1                         Size:34,36,38,40  3499       2449        30
# 2              Size:Large,X-Large,XX-Large  1199        599        50
# 3          Size:Large,Medium,Small,X-Large  2299       1379        40
# 4                   Size:26,28,30,32,34,36  1699        849        50
#
#       Category
# 0  Westernwear
# 1  Westernwear
# 2  Westernwear
# 3  Westernwear
# 4  Westernwear

# %%
df['Sizes'] = df['Sizes'].str.replace("Size:", "")

# %%
df['Sizes']
# Out:
# 0        Large,Medium,Small,X-Large,X-Small
# 1                               34,36,38,40
# 2                    Large,X-Large,XX-Large
# 3                Large,Medium,Small,X-Large
# 4                         26,28,30,32,34,36
#                         ...
# 26673                        36,37,38,39,40
# 26674                        36,37,38,39,40
# 26885                            Error Size
# 27290                            Error Size
# 28418                            Error Size
# Name: Sizes, Length: 18374, dtype: object

# %%
df.head()
# Out:
#      BrandName                                            Deatils  \
# 0         life  solid cotton blend collar neck womens a-line d...
# 1         only  polyester peter pan collar womens blouson dres...
# 2      fratini  solid polyester blend wide neck womens regular...
# 3  zink london  stripes polyester sweetheart neck womens dress...
# 4         life  regular fit regular length denim womens jeans ...
#
#                                 Sizes   MRP  SellPrice  Discount     Category
# 0  Large,Medium,Small,X-Large,X-Small  1699        849        50  Westernwear
# 1                         34,36,38,40  3499       2449        30  Westernwear
# 2              Large,X-Large,XX-Large  1199        599        50  Westernwear
# 3          Large,Medium,Small,X-Large  2299       1379        40  Westernwear
# 4                   26,28,30,32,34,36  1699        849        50  Westernwear

# %%
df = df[df["Sizes"] != "Error Size"]

# %%
df.Sizes
# Out:
# 0        Large,Medium,Small,X-Large,X-Small
# 1                               34,36,38,40
# 2                    Large,X-Large,XX-Large
# 3                Large,Medium,Small,X-Large
# 4                         26,28,30,32,34,36
#                         ...
# 26664                        36,37,38,39,40
# 26666                        36,37,38,39,40
# 26669                                 38,40
# 26673                        36,37,38,39,40
# 26674                        36,37,38,39,40
# Name: Sizes, Length: 18371, dtype: object

# %%
df['Sizes']
# Out:
# 0        Large,Medium,Small,X-Large,X-Small
# 1                               34,36,38,40
# 2                    Large,X-Large,XX-Large
# 3                Large,Medium,Small,X-Large
# 4                         26,28,30,32,34,36
#                         ...
# 26664                        36,37,38,39,40
# 26666                        36,37,38,39,40
# 26669                                 38,40
# 26673                        36,37,38,39,40
# 26674                        36,37,38,39,40
# Name: Sizes, Length: 18371, dtype: object

# %%
df[26885:28419]
# Out:
# Empty DataFrame
# Columns: [BrandName, Deatils, Sizes, MRP, SellPrice, Discount, Category]
# Index: []

# %%
df.tail()
# Out:
#             BrandName                                            Deatils  \
# 26664  lemon & pepper  pu back strap womens casual block heel sandals...
# 26666  lemon & pepper  synthetic patent open back womens party wedge ...
# 26669  signature sole     synthetic slipon womens casual flats - natural
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
#
#                 Sizes   MRP  SellPrice  Discount  Category
# 26664  36,37,38,39,40  2799       1959        30  Footwear
# 26666  36,37,38,39,40  2799       1959        30  Footwear
# 26669           38,40  1500        975        35  Footwear
# 26673  36,37,38,39,40  2999       1499        50  Footwear
# 26674  36,37,38,39,40  2199       1099        50  Footwear

# %%
df.describe()
# Out:
#                 MRP     SellPrice      Discount
# count  18371.000000  18371.000000  18371.000000
# mean    2135.781395   1163.270644     45.283327
# std     1185.291937    743.092821     14.203077
# min      171.000000    114.000000      0.000000
# 25%     1299.000000    659.000000     35.000000
# 50%     1899.000000    995.000000     50.000000
# 75%     2656.500000   1469.000000     50.000000
# max    16999.000000  13599.000000     85.000000

# %%
#Here we can say that Max MRP is 18371 and Max SP is 18371 and Min MRP is 171 and min SP is 114.

# %%
# Handling discount column

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df["Discount"].unique()
# Out:
# array([50, 30, 40, 10, 60, 20, 41, 55, 73, 69, 47, 57, 70, 67, 33, 44, 35,
#        45, 65, 68, 17, 78, 25, 80, 64, 63, 32, 26, 71, 75, 79, 61, 24, 62,
#        38, 43, 54, 23, 27, 42, 76, 72, 53, 12, 58, 74, 56, 22, 66, 39, 15,
#        34, 85, 77,  4,  5, 51, 37, 48,  0, 52, 29, 28, 36])

# %%
df["Discount"]
# Out:
# 0        50
# 1        30
# 2        50
# 3        40
# 4        50
#          ..
# 26664    30
# 26666    30
# 26669    35
# 26673    50
# 26674    50
# Name: Discount, Length: 18371, dtype: int64

# %%
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26664  lemon & pepper  pu back strap womens casual block heel sandals...
# 26666  lemon & pepper  synthetic patent open back womens party wedge ...
# 26669  signature sole     synthetic slipon womens casual flats - natural
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
#
#                                     Sizes   MRP  SellPrice  Discount  \
# ...

# %%
def discount_range(i):
        if i in range(0,26):
            return str("0-25%")
        elif i in range(26,51):
            return str("26-50%")
        elif i in range(51,76):
            return str("51-75%")
        else:
            return str(">75%")
df["Discount_range"] = df["Discount"].apply(discount_range)
df.head()
# Out:
#      BrandName                                            Deatils  \
# 0         life  solid cotton blend collar neck womens a-line d...
# 1         only  polyester peter pan collar womens blouson dres...
# 2      fratini  solid polyester blend wide neck womens regular...
# 3  zink london  stripes polyester sweetheart neck womens dress...
# 4         life  regular fit regular length denim womens jeans ...
#
#                                 Sizes   MRP  SellPrice  Discount     Category  \
# 0  Large,Medium,Small,X-Large,X-Small  1699        849        50  Westernwear
# 1                         34,36,38,40  3499       2449        30  Westernwear
# 2              Large,X-Large,XX-Large  1199        599        50  Westernwear
# 3          Large,Medium,Small,X-Large  2299       1379        40  Westernwear
# 4                   26,28,30,32,34,36  1699        849        50  Westernwear
#
#   Discount_range
# 0         26-50%
# 1         26-50%
# 2         26-50%
# 3         26-50%
# ...

# %%
df.rename(columns = {"Discount":"Discount_in_%"}, inplace = True)

# %%
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26664  lemon & pepper  pu back strap womens casual block heel sandals...
# 26666  lemon & pepper  synthetic patent open back womens party wedge ...
# 26669  signature sole     synthetic slipon womens casual flats - natural
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
#
#                                     Sizes   MRP  SellPrice  Discount_in_%  \
# ...

# %%
# Data Visualisation

# %%
df["Discount_range"].value_counts()
# Out:
# 26-50%    11676
# 51-75%     4485
# 0-25%      2120
# >75%         90
# Name: Discount_range, dtype: int64

# %%
plt.figure(figsize=(20, 8))
df["Discount_range"].value_counts().plot.bar(fontsize=15)

# %%
# Clearly we can see that mostly brands provide discounts between 26-50%, hence maximum sales in this range

# %%
# Category wise most purchased sizes with its details

# %%
df["Category"].unique()
# Out:
# array(['Westernwear', 'Indianwear', 'Lingerie&Nightwear', 'Footwear'],
#       dtype=object)

# %%
Category_df = df[df["Category"] == "Westernwear"]

# %%
Category_df.head(5)
# Out:
#      BrandName                                            Deatils  \
# 0         life  solid cotton blend collar neck womens a-line d...
# 1         only  polyester peter pan collar womens blouson dres...
# 2      fratini  solid polyester blend wide neck womens regular...
# 3  zink london  stripes polyester sweetheart neck womens dress...
# 4         life  regular fit regular length denim womens jeans ...
#
#                                 Sizes   MRP  SellPrice  Discount_in_%  \
# 0  Large,Medium,Small,X-Large,X-Small  1699        849             50
# 1                         34,36,38,40  3499       2449             30
# 2              Large,X-Large,XX-Large  1199        599             50
# 3          Large,Medium,Small,X-Large  2299       1379             40
# 4                   26,28,30,32,34,36  1699        849             50
#
#       Category Discount_range
# 0  Westernwear         26-50%
# 1  Westernwear         26-50%
# 2  Westernwear         26-50%
# ...

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS

# %%
text = " ".join(i for i in Category_df.Deatils)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# text = " ".join(i for i in Category_df.Deatils)
# stopwords = set(STOPWORDS)
# wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
# plt.figure( figsize=(15,10))
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
# plt.show()

# %%
# Mostly women preferring round neck cotton regular fit tshirt

# %%
Category_indianwear = df[df["Category"]=="Indianwear"]

# %%
Category_indianwear.head()
# Out:
#       BrandName                                            Deatils  \
# 10374      stop  solid rayon collar neck womens casual tunic - ...
# 10375    infuse  printed round neck cotton flex womens gather d...
# 10376   kashish  solid viscose blend straight fit womens festiv...
# 10377   juniper  printed rayon mandarin womens kurta palazzo se...
# 10378   kashish  embroidered viscose blend round neck womens fe...
#
#                                              Sizes   MRP  SellPrice  \
# 10374               XL,Large,Medium,Small,XX-Large   999        499
# 10375          Large,Medium,Small,X-Small,XX-Large  1199        479
# 10376                                 Small/Medium   799        399
# 10377          Large,Medium,Small,X-Large,XX-Large  2999        899
# 10378  Large,Medium,Small,X-Large,X-Small,XX-Large  3499       1749
#
#        Discount_in_%    Category Discount_range
# 10374             50  Indianwear         26-50%
# 10375             60  Indianwear         51-75%
# ...
